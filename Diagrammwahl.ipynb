# %%
import matplotlib.pyplot as plt

# %%
monate = ['Jan', 'Feb', 'Mär', 'Apr', 'Mai', 'Jun']
umsatz = [12000, 13500, 15000, 11000, 13000, 12500]

# %%
plt.plot(monate, umsatz, marker='o', color='blue', linestyle='-')
plt.title('Monatsumsätze Filiale A')
plt.xlabel('Monat')
plt.ylabel('Umsatz in €')
plt.grid(True)
