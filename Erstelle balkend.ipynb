# %%
import matplotlib.pyplot as plt

# %%
monate = ['Jan', 'Feb', 'Mär', 'Apr', 'Mai', 'Jun']
umsatz_b = [13200, 11000, 12500, 14000, 12000, 15000]

# %%
plt.bar(monate, umsatz_b)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(monate, umsatz_b)
plt.title("Umsätze der Filiale B (Jan–Jun)")
plt.xlabel("Monat")
plt.ylabel("Umsatz in €")
plt.show ()

# %%
plt.savefig("umsatzdiagramm.png", dpi=300)
plt.show()

# %%
import xlsxwriter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import xlsxwriter
#
# ModuleNotFoundError: No module named 'xlsxwriter'
