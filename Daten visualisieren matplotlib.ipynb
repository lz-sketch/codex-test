# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    "Monat": ["Jan", "Feb", "März"],
    "A": [12000, 13000, 15000],
    "B": [10000, 10500, 9800],
    "C": [11000, 11500, 10900]
})

# %%
df.set_index("Monat").plot(kind="bar")  # Säulendiagramm
plt.title("Umsatzvergleich Januar–März")
plt.ylabel("Umsatz in €")
plt.xlabel("Monat")
plt.tight_layout()
plt.show()

# %%
jupyter nbconvert Daten visualisieren.ipynb --to pdf
# Out:
#   Cell In[5], line 1
#     jupyter nbconvert Daten visualisieren.ipynb --to pdf
#             ^
# SyntaxError: invalid syntax

# %%
jupyter nbconvert Daten/ visualisieren/ matplotlib.ipynb --to html --execute --output Daten/ visualisieren/ matplotlib.html
# Out:
#   Cell In[3], line 1
#     jupyter nbconvert Daten/ visualisieren/ matplotlib.ipynb --to html --execute --output Daten/ visualisieren/ matplotlib.html
#             ^
# SyntaxError: invalid syntax

# %%
# !jupyter nbconvert Daten_visualisieren_matplotlib.ipynb --to html!dir
# Out:
# 2_Diagrammwahl.ipynb
# Abschlussarbeit
# Daten\ visualisieren\ matplotlib.ipynb
# Diagrammwahl.ipynb
# Durchschnitt_berechnen.py
# Erste\ Analyse.ipynb
# Erstelle\ balkend.ipynb
# Filiale_hoechster_Umsatz_März.py
# Filter_alle_Filialen_Januar_größer_11000.py
# Hoechsten_Umsatz_ermitteln_März.py
# Umsatzdaten.csv
# Untitled5.ipynb
# anaconda_projects
# scikitlearn.ipynb
# umsatzdiagramm.png
